# %%
import os
import netCDF4
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime, timezone, timedelta

# %%
nc = netCDF4.Dataset("delft3d-flow_joux_20251130.nc")
print(nc)
